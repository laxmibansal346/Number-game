# %% [markdown]
# <a href="https://colab.research.google.com/github/laxmibansal346/python-learning-labs/blob/main/Copy_of_Module3_Activity3_1_Pandas_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Module 3 – Activity 3.1
# ## Pandas Hands-on Lab (5 Marks)
#
# **Instructions:**
# - Complete all tasks
# - Write code in the given cells
# - Run each cell and show outputs
# - Add comments wherever required
# - Submit the completed notebook (PDF) on LMS
#
# **Name:** laxmi basnal
# **Roll No.:** betn1ai25226
# **Course:** Data Analytics Using Python (AIL0202)
#
# colab link
#
# https://colab.research.google.com/drive/12-8rsCkkr4IuS8SZNohnhCC3nAJ34iQs#scrollTo=t87JzGflhXZD

# %%
# Import required libraries
# Write code to import pandas and numpy

# %% [markdown]
# ## Task 1: Data Creation & Loading (1 Mark)
# Dataset:
#     'Name': ['Aman','Riya','Rahul','Sneha','Karan'],
#     'Department': ['IT','HR','IT','Finance','HR'],
#     'Salary': [50000,60000,55000,65000,52000]

# %%
# Create:
# 1. A Pandas Series from a list of 5 elements
import pandas as pd

s = pd.Series([1, 2, 3, 4, 5])
print(s)
data = {
    'Name': ['Aman','Riya','Rahul','Sneha','Karan'],
    'Department': ['IT','HR','IT','Finance','HR'],
    'Salary': [50000,60000,55000,65000,52000]
}
# 2. A DataFrame with columns: Name, Department, Salary
df = pd.DataFrame(data)
print(df)
# 3. Write a dataset using (any one): CSV / Excel / JSON
df.to_csv("data.csv", index=False)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
#     Name Department  Salary
# 0   Aman         IT   50000
# 1   Riya         HR   60000
# 2  Rahul         IT   55000
# 3  Sneha    Finance   65000
# 4  Karan         HR   52000

# %% [markdown]
# ## Task 2: Data Exploration (1 Mark)

# %%
# Perform:
# Display first 3 rows

df = pd.DataFrame(data)

print(df.head(3))
print("\n")
# Display dataset information
print(df.info())
print("\n")
# Display dataset information
print(df.describe())
# Out:
#     Name Department  Salary
# 0   Aman         IT   50000
# 1   Riya         HR   60000
# 2  Rahul         IT   55000
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        5 non-null      object
#  1   Department  5 non-null      object
#  2   Salary      5 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 252.0+ bytes
# None
#
#
#              Salary
# count      5.000000
# mean   56400.000000
# std     6107.372594
# min    50000.000000
# 25%    52000.000000
# 50%    55000.000000
# 75%    60000.000000
# max    65000.000000

# %% [markdown]
# ## Task 3: Indexing, Filtering & Sorting (1 Mark)

# %%
# Perform:
# 1. Extract first 3 rows using .loc[]
# 2. Extract Salary column using .iloc[]
# 3. Filter employees with Salary > 55000
# 4. Sort dataset by Salary (descending)


data = {
    'Name': ['Aman','Riya','Rahul','Sneha','Karan'],
    'Department': ['IT','HR','IT','Finance','HR'],
    'Salary': [50000,60000,55000,65000,52000]
}
#1. Extract first 3 rows using .loc[]
print(df.loc[0:2])
print("\n")

# 3. Filter employees with Salary > 55000
print(df[df['Salary'] > 55000])
# Out:
#     Name Department  Salary
# 0   Aman         IT   50000
# 1   Riya         HR   60000
# 2  Rahul         IT   55000
#
#
#     Name Department  Salary
# 1   Riya         HR   60000
# 3  Sneha    Finance   65000

# %% [markdown]
# ## Task 4: Group-by & Aggregation (1 Mark)

# %%
# Perform:
# 1. Find average salary department-wise
# 2. Find total and count of employees per department
import pandas as pd

data = {
    'Name': ['Aman','Riya','Rahul','Sneha','Karan'],
    'Department': ['IT','HR','IT','Finance','HR'],
    'Salary': [50000,60000,55000,65000,52000]
}

# 1. Find average salary department-wise
print(df.groupby('Department')['Salary'].mean())
print("\n")
# 2. Find total and count of employees per department


print(df.groupby('Department')['Salary'].sum())
# Out:
# Department
# Finance    65000.0
# HR         56000.0
# IT         52500.0
# Name: Salary, dtype: float64
#
#
# Department
# Finance     65000
# HR         112000
# IT         105000
# Name: Salary, dtype: int64

# %% [markdown]
# ## Task 5: Data Cleaning & Time-Series (1 Mark)

# %%
# Given:
# df['Joining_Date'] = ['2022-01-10','2021-07-15','2023-03-12','2020-11-05','2022-05-20']

# Perform:
# 1. Convert Joining_Date to datetime
# 2. Extract Year and Month
# 3. Identify duplicate rows
# 4. Remove duplicate rows
